# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1. Write a Python program to read the contents of a text file and print them to the console.
with open('/content/export.txt', 'r') as file:
  contents = file.read()
  print(contents)
# Out:
# day 1:-
# keywords:-amazon example, then indiamart keywords
# importance of groups and categories
# meamoshop Korean skincare dropshipping
# 8 months target to get 75 lead package and pay for it via this package
#
# day 2:-
# buy leads mapping:-make sure to take leads of products that u have listed but not yet taken any leads of(products-category report-buy lead mapping)
# catalogue views
# sometimes there are wrong product images or process on website so change it
# follow a script diligently with the customer till u receive payment
#
# social medias:-imo(us)
# viber
# kakao
# telegram
# signal
#
# ask how to identify enquiry if it from mobile,or mail or portal?
#
# day 3:-
# follow a routine to be successful otherwise u never will be. Every successful man to exist had folloed a routine.
# read the 2 books to build urself up that'll help u in all aspects of life not just business. Once u understand that book ull have control over everything in ur life ad nothing will be impossible.
# ...

# %%
#2. Write a Python program to write a list of strings to a text file, each on a new line.

# List of strings to write
my_strings = ["Hi", "!!", "This", "Is", "A", "Test"]

# Open the file in write mode
with open("/content/to play.txt", "w") as file:
  # Write each string to the file on a new line
  for string in my_strings:
    file.write(string + "\n")
with open('/content/to play.txt', 'r') as file:
  contents = file.read()
  print(contents)
# Out:
# Hi
# !!
# This
# Is
# A
# Test

# %%
#3. Simple Data Analysis with pandas
#Write a Python program that loads a CSV file into a pandas DataFrame and performs the following operations:
#Display the first few rows of the DataFrame.

df = pd.read_csv('/content/IT Salary Survey EU (Responses) - Dec 2020.csv')
print(df.head())
df.info()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
#Calculate and display basic statistics (mean, median, mode) for numerical columns.
df=df.dropna()
print("mean= ",df["Age"].mean(numeric_only=True))
print("median= ",df["Age"].median(numeric_only=True))
print("mode= ",df["Age"].mode())

print("\nmean= ",df["Yearly brutto salary (without bonus and stocks) in EUR"].mean(numeric_only=True))
print("median= ",df["Yearly brutto salary (without bonus and stocks) in EUR"].median(numeric_only=True))
print("mode= ",df["Yearly brutto salary (without bonus and stocks) in EUR"].mode())
# Out:
# mean=  33.01324503311258
# median=  33.0
# mode=  0    33.0
# Name: Age, dtype: float64
#
# mean=  74163.09271523179
# median=  73700.0
# mode=  0    75000.0
# Name: Yearly brutto salary (without bonus and stocks) in EUR, dtype: float64

# %%
#Filter the DataFrame to display rows that meet certain criteria.

print(df[(df['Age']>=20)&(df['Age']<22)])
# Out:
#                 Timestamp   Age  Gender     City          Position   \
# 1302  01/12/2021 10:43:29  20.0  Female  Cologne  Software Engineer
#
#      Total years of experience Years of experience in Germany Seniority level  \
# 1302                       800                            800             800
#
#      Your main technology / programming language  \
# 1302                                         800
#
#      Other technologies/programming languages you use often  ...  \
# 1302                                             Docker      ...
#
#       Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 1302                                              12000
#
#      Number of vacation days  Employment status   Сontract duration  \
# 1302                   12000            Founder  Temporary contract
#
#      Main language at work Company size Company type  \
# 1302                German     up to 10      Startup
#
# ...

# %%
#Building a Simple Machine Learning Model
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
lf= pd.read_csv('/content/housing.csv', header=None, delimiter=r"\s+", names=column_names)
lf
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
#Display the first few rows of the dataset.
lf.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
#Get a summary of the dataset (mean, median, standard deviation, etc.).
lf.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#Selecting 'RM' (average number of rooms per dwelling) feature to predict the 'MEDV' (median value of owner-occupied homes).
x= lf['RM'].values.reshape(-1, 1)
y= lf['MEDV']

# %%
#Split the dataset into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=40)

# %%
#Initialize and train a Linear Regression model using the training set
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Use the trained model to make predictions on the test set
y_pred = model.predict(x_test)

new_x = np.array([[6.575]])
new_y_pred = model.predict(new_x)
print(new_y_pred)
# Out:
# [24.96790891]

# %%
#Evaluate the model's performance using metrics such as Mean Squared Error (MSE) and R-squared (R²).
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 58.28784516429005
# R-squared: 0.5153692057519232

# %%
#Create a scatter plot to visualize the actual vs. predicted values
plt.scatter(x_test, y_test, color='blue')
plt.plot(x_test, y_pred, color='red')
